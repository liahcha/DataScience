# %% [markdown]
# ## Residual nets for image classification, on CIFAR-10

# %%
### Step 1: Import modules

import numpy as np

import os

import keras
import keras.backend as K

from keras import layers
from keras.models import Input, Model, load_model
from keras.layers.core import Dense, Activation, Flatten, Dropout
from keras.layers.convolutional import Conv2D
from keras.layers.pooling import MaxPooling2D, AveragePooling2D
from keras.layers.normalization import BatchNormalization
from keras.datasets import cifar10


## Fix random seed for reproducibility
np.random.seed(20170706)


## Check proper working directory
path = os.getcwd()
os.chdir(path)
if os.getcwd().split('/')[-1] == 'DLdata':
    pass
else:
    path = os.getcwd()+'/DLdata'
    #raise OSError('Check current working directory.\n'
    #              'If not specified as instructed, '
    #              'more errors will occur throught the code.\n'
    #              '- Current working directory: %s' % os.getcwd())
print(path)



####################################################################################


### Step 2: Load & preprocess data


## 2-1. Load
(X_train, y_train), (X_test, y_test) = cifar10.load_data()

## 2-2. Preprocess
# Change data types to 'float32'
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')

# Normalization
X_train /= 255
X_test /= 255

# Check shapes of train / test data
assert  X_train.shape == (50000, 32, 32, 3) and X_test.shape == (10000, 32, 32, 3)
print('X_train shape:', X_train.shape)
print('X_test shape:', X_test.shape)

# Convert class vectors to binary class matrices (one-hot vectors)
Y_train = keras.utils.to_categorical(y_train, 10)
Y_test = keras.utils.to_categorical(y_test, 10)
print('Y_train shape:', Y_train.shape)
print('Y_test shape:', Y_test.shape)


####################################################################################

### Step 3: Build model

## 3-1. Define hyperparameters

epochs = 30
batch_size = 128
num_classes = 10

## 3-2. Define ResNet model customized on MNIST data

# DEFINE INPUT TENSOR
inputs = Input(shape=(32, 32, 3)) # image sahpe = 32*32, channel 3

bn_axis= 3

# TODO: WRITE CODE FOR RESNET (OF YOUR PREFERENCE)
x = Conv2D(64, (3,3), padding='same', strides=(2,2), name='conv1')(inputs)
x = BatchNormalization(axis=bn_axis, name='bn_conv1')(x)
x = Activation('relu')(x)

x = Conv2D(128, (3,3), padding='same', strides=(2,2), name='conv2')(x)
x = BatchNormalization(axis=bn_axis, name='bn_von2')(x)
x = Activation('relu')(x)

shortcut1 = Conv2D(128, (1,1), strides=(4, 4), name='conv5')(inputs)
shortcut1 = BatchNormalization(axis=bn_axis, name='reshape1')(shortcut1)
x = keras.layers.add([x, shortcut1])

x2 = Conv2D(256, (3,3), padding='same', strides=(2,2), name='conv3')(x)
x2 = BatchNormalization(axis=bn_axis, name='bn_von3')(x2)
x2 = Activation('relu')(x2)

x2 = Conv2D(512, (3,3), padding='same', strides=(1,1), name='conv4')(x2)
x2 = BatchNormalization(axis=bn_axis, name='bn_von4')(x2)

shortcut2 = Conv2D(512, (1,1), strides=(2,2), name='conv9')(x)
shortcut2 = BatchNormalization(axis=bn_axis, name='reshape2')(shortcut2)

x2 = keras.layers.add([x2, shortcut2])
x2 = Activation('relu')(x2)
x2 = Flatten(name='flatten')(x2)

# Softmax layer for predictions: (512, ) --> (10, ) 
predictions = Dense(10, activation='softmax', name='prediction')(x2)

# Instantiate model
model = Model(inputs=inputs, outputs=predictions, name='resnet_cifar10')


model.summary()

####################################################################################


### Step 4: Define callbacks

from keras.callbacks import TensorBoard

# List of callbacks
callbacks = []

# Tensorboard for visualization; only available with tensorflow backend
# In the terminal; tensorboard --logdir='/full/path/to/resnet_cifar10_logs/'
if K.backend() == 'tensorflow':
    print('Using tensorboard callback')
    tb_logdir = path+'/resnet_cifar10_logs/'
    if not os.path.exists(tb_logdir):
        os.makedirs(tb_logdir)
    tensorboard = TensorBoard(log_dir=tb_logdir,
                              histogram_freq=1,
                              write_graph=True)
    callbacks.append(tensorboard)
    
    
####################################################################################

### Step 5: Compile & train model


model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])


print(model.summary())


history = model.fit(X_train, Y_train,
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    callbacks=callbacks,
                    validation_split=0.1)


####################################################################################


### Step 6: Save & load weights

# Save model weights
model.save_weights(path+'/weights/resnet_cifar10_weights.h5')


####################################################################################


### Step 7: Test model performance
test_scores = model.evaluate(X_test, Y_test, verbose=1)
print("Test accuracy: %.2f%%" % (test_scores[1] * 100))
#train_scores = model.evaluate(X_train, Y_train, verbose=1)
#print("Train accuracy: %.2f%%" % (train_scores[1] * 100))


####################################################################################
# Out:
# /home/user/DataScience/DataScience/Study Note/Deep Learning/DLdata
# X_train shape: (50000, 32, 32, 3)
# X_test shape: (10000, 32, 32, 3)
# Y_train shape: (50000, 10)
# Y_test shape: (10000, 10)
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_2 (InputLayer)             (None, 32, 32, 3)     0
# ____________________________________________________________________________________________________
# conv1 (Conv2D)                   (None, 16, 16, 64)    1792        input_2[0][0]
# ____________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)    (None, 16, 16, 64)    256         conv1[0][0]
# ____________________________________________________________________________________________________
# activation_4 (Activation)        (None, 16, 16, 64)    0           bn_conv1[0][0]
# ____________________________________________________________________________________________________
# conv2 (Conv2D)                   (None, 8, 8, 128)     73856       activation_4[0][0]
# ____________________________________________________________________________________________________
# bn_von2 (BatchNormalization)     (None, 8, 8, 128)     512         conv2[0][0]
# ____________________________________________________________________________________________________
# conv5 (Conv2D)                   (None, 8, 8, 128)     512         input_2[0][0]
# ____________________________________________________________________________________________________
# activation_5 (Activation)        (None, 8, 8, 128)     0           bn_von2[0][0]
# ____________________________________________________________________________________________________
# reshape1 (BatchNormalization)    (None, 8, 8, 128)     512         conv5[0][0]
# ____________________________________________________________________________________________________
# add_3 (Add)                      (None, 8, 8, 128)     0           activation_5[0][0]
#                                                                    reshape1[0][0]
# ____________________________________________________________________________________________________
# conv3 (Conv2D)                   (None, 4, 4, 256)     295168      add_3[0][0]
# ____________________________________________________________________________________________________
# bn_von3 (BatchNormalization)     (None, 4, 4, 256)     1024        conv3[0][0]
# ____________________________________________________________________________________________________
# activation_6 (Activation)        (None, 4, 4, 256)     0           bn_von3[0][0]
# ____________________________________________________________________________________________________
# conv4 (Conv2D)                   (None, 4, 4, 512)     1180160     activation_6[0][0]
# ____________________________________________________________________________________________________
# conv9 (Conv2D)                   (None, 4, 4, 512)     66048       add_3[0][0]
# ____________________________________________________________________________________________________
# bn_von4 (BatchNormalization)     (None, 4, 4, 512)     2048        conv4[0][0]
# ____________________________________________________________________________________________________
# reshape2 (BatchNormalization)    (None, 4, 4, 512)     2048        conv9[0][0]
# ____________________________________________________________________________________________________
# add_4 (Add)                      (None, 4, 4, 512)     0           bn_von4[0][0]
#                                                                    reshape2[0][0]
# ____________________________________________________________________________________________________
# activation_7 (Activation)        (None, 4, 4, 512)     0           add_4[0][0]
# ____________________________________________________________________________________________________
# flatten (Flatten)                (None, 8192)          0           activation_7[0][0]
# ____________________________________________________________________________________________________
# prediction (Dense)               (None, 10)            81930       flatten[0][0]
# ====================================================================================================
# Total params: 1,705,866
# Trainable params: 1,702,666
# Non-trainable params: 3,200
# ____________________________________________________________________________________________________
# Using tensorboard callback
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_2 (InputLayer)             (None, 32, 32, 3)     0
# ____________________________________________________________________________________________________
# conv1 (Conv2D)                   (None, 16, 16, 64)    1792        input_2[0][0]
# ____________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)    (None, 16, 16, 64)    256         conv1[0][0]
# ____________________________________________________________________________________________________
# activation_4 (Activation)        (None, 16, 16, 64)    0           bn_conv1[0][0]
# ____________________________________________________________________________________________________
# conv2 (Conv2D)                   (None, 8, 8, 128)     73856       activation_4[0][0]
# ____________________________________________________________________________________________________
# bn_von2 (BatchNormalization)     (None, 8, 8, 128)     512         conv2[0][0]
# ____________________________________________________________________________________________________
# conv5 (Conv2D)                   (None, 8, 8, 128)     512         input_2[0][0]
# ____________________________________________________________________________________________________
# activation_5 (Activation)        (None, 8, 8, 128)     0           bn_von2[0][0]
# ____________________________________________________________________________________________________
# reshape1 (BatchNormalization)    (None, 8, 8, 128)     512         conv5[0][0]
# ____________________________________________________________________________________________________
# add_3 (Add)                      (None, 8, 8, 128)     0           activation_5[0][0]
#                                                                    reshape1[0][0]
# ____________________________________________________________________________________________________
# conv3 (Conv2D)                   (None, 4, 4, 256)     295168      add_3[0][0]
# ____________________________________________________________________________________________________
# bn_von3 (BatchNormalization)     (None, 4, 4, 256)     1024        conv3[0][0]
# ____________________________________________________________________________________________________
# activation_6 (Activation)        (None, 4, 4, 256)     0           bn_von3[0][0]
# ____________________________________________________________________________________________________
# conv4 (Conv2D)                   (None, 4, 4, 512)     1180160     activation_6[0][0]
# ____________________________________________________________________________________________________
# conv9 (Conv2D)                   (None, 4, 4, 512)     66048       add_3[0][0]
# ____________________________________________________________________________________________________
# bn_von4 (BatchNormalization)     (None, 4, 4, 512)     2048        conv4[0][0]
# ____________________________________________________________________________________________________
# reshape2 (BatchNormalization)    (None, 4, 4, 512)     2048        conv9[0][0]
# ____________________________________________________________________________________________________
# add_4 (Add)                      (None, 4, 4, 512)     0           bn_von4[0][0]
#                                                                    reshape2[0][0]
# ____________________________________________________________________________________________________
# activation_7 (Activation)        (None, 4, 4, 512)     0           add_4[0][0]
# ____________________________________________________________________________________________________
# flatten (Flatten)                (None, 8192)          0           activation_7[0][0]
# ____________________________________________________________________________________________________
# prediction (Dense)               (None, 10)            81930       flatten[0][0]
# ====================================================================================================
# Total params: 1,705,866
# Trainable params: 1,702,666
# Non-trainable params: 3,200
# ____________________________________________________________________________________________________
# None
# Train on 45000 samples, validate on 5000 samples
# INFO:tensorflow:Summary name conv1_1/kernel:0 is illegal; using conv1_1/kernel_0 instead.
# INFO:tensorflow:Summary name conv1_1/bias:0 is illegal; using conv1_1/bias_0 instead.
# INFO:tensorflow:Summary name bn_conv1_1/gamma:0 is illegal; using bn_conv1_1/gamma_0 instead.
# INFO:tensorflow:Summary name bn_conv1_1/beta:0 is illegal; using bn_conv1_1/beta_0 instead.
# INFO:tensorflow:Summary name bn_conv1_1/moving_mean:0 is illegal; using bn_conv1_1/moving_mean_0 instead.
# INFO:tensorflow:Summary name bn_conv1_1/moving_variance:0 is illegal; using bn_conv1_1/moving_variance_0 instead.
# INFO:tensorflow:Summary name conv2_1/kernel:0 is illegal; using conv2_1/kernel_0 instead.
# INFO:tensorflow:Summary name conv2_1/bias:0 is illegal; using conv2_1/bias_0 instead.
# INFO:tensorflow:Summary name bn_von2_1/gamma:0 is illegal; using bn_von2_1/gamma_0 instead.
# INFO:tensorflow:Summary name bn_von2_1/beta:0 is illegal; using bn_von2_1/beta_0 instead.
# INFO:tensorflow:Summary name bn_von2_1/moving_mean:0 is illegal; using bn_von2_1/moving_mean_0 instead.
# INFO:tensorflow:Summary name bn_von2_1/moving_variance:0 is illegal; using bn_von2_1/moving_variance_0 instead.
# INFO:tensorflow:Summary name conv5_1/kernel:0 is illegal; using conv5_1/kernel_0 instead.
# INFO:tensorflow:Summary name conv5_1/bias:0 is illegal; using conv5_1/bias_0 instead.
# INFO:tensorflow:Summary name reshape1_1/gamma:0 is illegal; using reshape1_1/gamma_0 instead.
# INFO:tensorflow:Summary name reshape1_1/beta:0 is illegal; using reshape1_1/beta_0 instead.
# INFO:tensorflow:Summary name reshape1_1/moving_mean:0 is illegal; using reshape1_1/moving_mean_0 instead.
# INFO:tensorflow:Summary name reshape1_1/moving_variance:0 is illegal; using reshape1_1/moving_variance_0 instead.
# INFO:tensorflow:Summary name conv3_1/kernel:0 is illegal; using conv3_1/kernel_0 instead.
# INFO:tensorflow:Summary name conv3_1/bias:0 is illegal; using conv3_1/bias_0 instead.
# INFO:tensorflow:Summary name bn_von3_1/gamma:0 is illegal; using bn_von3_1/gamma_0 instead.
# INFO:tensorflow:Summary name bn_von3_1/beta:0 is illegal; using bn_von3_1/beta_0 instead.
# INFO:tensorflow:Summary name bn_von3_1/moving_mean:0 is illegal; using bn_von3_1/moving_mean_0 instead.
# INFO:tensorflow:Summary name bn_von3_1/moving_variance:0 is illegal; using bn_von3_1/moving_variance_0 instead.
# INFO:tensorflow:Summary name conv4_1/kernel:0 is illegal; using conv4_1/kernel_0 instead.
# INFO:tensorflow:Summary name conv4_1/bias:0 is illegal; using conv4_1/bias_0 instead.
# INFO:tensorflow:Summary name conv9_1/kernel:0 is illegal; using conv9_1/kernel_0 instead.
# INFO:tensorflow:Summary name conv9_1/bias:0 is illegal; using conv9_1/bias_0 instead.
# INFO:tensorflow:Summary name bn_von4_1/gamma:0 is illegal; using bn_von4_1/gamma_0 instead.
# INFO:tensorflow:Summary name bn_von4_1/beta:0 is illegal; using bn_von4_1/beta_0 instead.
# INFO:tensorflow:Summary name bn_von4_1/moving_mean:0 is illegal; using bn_von4_1/moving_mean_0 instead.
# INFO:tensorflow:Summary name bn_von4_1/moving_variance:0 is illegal; using bn_von4_1/moving_variance_0 instead.
# INFO:tensorflow:Summary name reshape2_1/gamma:0 is illegal; using reshape2_1/gamma_0 instead.
# INFO:tensorflow:Summary name reshape2_1/beta:0 is illegal; using reshape2_1/beta_0 instead.
# INFO:tensorflow:Summary name reshape2_1/moving_mean:0 is illegal; using reshape2_1/moving_mean_0 instead.
# INFO:tensorflow:Summary name reshape2_1/moving_variance:0 is illegal; using reshape2_1/moving_variance_0 instead.
# INFO:tensorflow:Summary name prediction/kernel:0 is illegal; using prediction/kernel_0 instead.
# INFO:tensorflow:Summary name prediction/bias:0 is illegal; using prediction/bias_0 instead.
# Epoch 1/30
# 45000/45000 [==============================] - 18s - loss: 2.2000 - acc: 0.4584 - val_loss: 2.7467 - val_acc: 0.2290
# Epoch 2/30
# 45000/45000 [==============================] - 17s - loss: 1.0565 - acc: 0.6301 - val_loss: 1.2380 - val_acc: 0.5790
# Epoch 3/30
# 45000/45000 [==============================] - 17s - loss: 0.8249 - acc: 0.7108 - val_loss: 1.0809 - val_acc: 0.6298
# Epoch 4/30
# 45000/45000 [==============================] - 17s - loss: 0.6497 - acc: 0.7733 - val_loss: 1.0691 - val_acc: 0.6584
# Epoch 5/30
# 45000/45000 [==============================] - 17s - loss: 0.4824 - acc: 0.8301 - val_loss: 1.6761 - val_acc: 0.5972
# Epoch 6/30
# 45000/45000 [==============================] - 17s - loss: 0.3360 - acc: 0.8846 - val_loss: 1.2675 - val_acc: 0.6556
# Epoch 7/30
# 45000/45000 [==============================] - 17s - loss: 0.2141 - acc: 0.9273 - val_loss: 2.1747 - val_acc: 0.5842
# Epoch 8/30
# 45000/45000 [==============================] - 17s - loss: 0.1452 - acc: 0.9502 - val_loss: 1.8752 - val_acc: 0.6328
# Epoch 9/30
# 45000/45000 [==============================] - 17s - loss: 0.1028 - acc: 0.9664 - val_loss: 1.7762 - val_acc: 0.6408
# Epoch 10/30
# 45000/45000 [==============================] - 17s - loss: 0.0901 - acc: 0.9698 - val_loss: 2.5116 - val_acc: 0.5728
# Epoch 11/30
# 45000/45000 [==============================] - 17s - loss: 0.0880 - acc: 0.9710 - val_loss: 3.6255 - val_acc: 0.5000
# Epoch 12/30
# 45000/45000 [==============================] - 17s - loss: 0.0685 - acc: 0.9764 - val_loss: 2.5894 - val_acc: 0.6132
# Epoch 13/30
# 45000/45000 [==============================] - 17s - loss: 0.0703 - acc: 0.9757 - val_loss: 1.8679 - val_acc: 0.6686
# Epoch 14/30
# 45000/45000 [==============================] - 17s - loss: 0.0560 - acc: 0.9816 - val_loss: 2.7120 - val_acc: 0.5966
# Epoch 15/30
# 45000/45000 [==============================] - 17s - loss: 0.0586 - acc: 0.9799 - val_loss: 1.9979 - val_acc: 0.6498
# Epoch 16/30
# 45000/45000 [==============================] - 17s - loss: 0.0607 - acc: 0.9800 - val_loss: 2.9267 - val_acc: 0.6030
# Epoch 17/30
# 45000/45000 [==============================] - 17s - loss: 0.0395 - acc: 0.9870 - val_loss: 1.6829 - val_acc: 0.6978
# Epoch 18/30
# 45000/45000 [==============================] - 17s - loss: 0.0335 - acc: 0.9885 - val_loss: 2.0448 - val_acc: 0.6794
# Epoch 19/30
# 45000/45000 [==============================] - 17s - loss: 0.0554 - acc: 0.9808 - val_loss: 2.0800 - val_acc: 0.6528
# Epoch 20/30
# 45000/45000 [==============================] - 17s - loss: 0.0538 - acc: 0.9814 - val_loss: 1.7810 - val_acc: 0.6968
# Epoch 21/30
# 45000/45000 [==============================] - 17s - loss: 0.0399 - acc: 0.9871 - val_loss: 2.0812 - val_acc: 0.6684
# Epoch 22/30
# 45000/45000 [==============================] - 17s - loss: 0.0401 - acc: 0.9861 - val_loss: 1.7039 - val_acc: 0.6878
# Epoch 23/30
# 45000/45000 [==============================] - 17s - loss: 0.0313 - acc: 0.9896 - val_loss: 2.3932 - val_acc: 0.6352
# Epoch 24/30
# 45000/45000 [==============================] - 17s - loss: 0.0337 - acc: 0.9884 - val_loss: 1.8489 - val_acc: 0.7104
# Epoch 25/30
# 45000/45000 [==============================] - 17s - loss: 0.0282 - acc: 0.9902 - val_loss: 1.7230 - val_acc: 0.7076
# Epoch 26/30
# 45000/45000 [==============================] - 17s - loss: 0.0311 - acc: 0.9896 - val_loss: 3.2946 - val_acc: 0.5928
# Epoch 27/30
# 45000/45000 [==============================] - 17s - loss: 0.0399 - acc: 0.9862 - val_loss: 3.1551 - val_acc: 0.6108
# Epoch 28/30
# 45000/45000 [==============================] - 17s - loss: 0.0276 - acc: 0.9907 - val_loss: 2.4767 - val_acc: 0.6420
# Epoch 29/30
# 45000/45000 [==============================] - 17s - loss: 0.0229 - acc: 0.9930 - val_loss: 1.8907 - val_acc: 0.6998
# Epoch 30/30
# 45000/45000 [==============================] - 17s - loss: 0.0274 - acc: 0.9907 - val_loss: 2.2566 - val_acc: 0.6824
#  9888/10000 [============================>.] - ETA: 0sTest accuracy: 67.06%
